# %% [markdown]
# # Binomial Distribution and Mendelian Inheritance

# %% [markdown]
# In this set of chapters we introduce the idea of plogenic inheritance by initially considering polgenic Mendelian inheritance that follows a Binomial distribution of probability. Firstly, it is necessary to intorduce the ideas of Mendelian gnetics and how the introduction of multiple genes result in a binomial distibution of probabilities for different combinations of 'Dominant' and 'Recessive' phenotypes.

# %% [markdown]
# ## Polygenic Mendelian Inheritance

# %% [markdown]
# In this chapter we aim to build a deductive model of Mendelian inheritance for more than one gene. It is a generalisation of the single gene bi-allelic model originally developed by Gregor Mendel. He proposed that the recessive allele would not be expressed as a phenotype unless it is homozygous. The table below oulines how the Dominant (D) and recessive (r) alleles combine to form the phenotype.

# %% [markdown]
# <img src="./images/Mendel-0.png" alt="alt_text" align="centre" width=150 height=150 >

# %% [markdown]
# Below, we can see the table above used to describe the probability of each combination of allele pair. Given that the dominant phenotypr always gets expressed if the allele D is present, the probability of expression of the dominant phenotypr is 0.75 = 𝛴 P(DD) + P(Dr) + P(rD), whereas the homozygous P(rr) = 0.25

# %% [markdown]
# <img src="./images/Mendel1.png" width=800 height=400>

# %% [markdown]
# Next, we can move on to consider a situation of Mendelian inheritance, when there are two genes (i.e. 4 alleles). The number of combinations now is 4^2 combinations of two genes (each with 4 configurations of alleles) possible. The probabilities are calculated as ,
# 1 x (.75)2 + 2 x (0.75)(0.25) + 1 x (0.25)2 = 1 = 0.5625 + 2x (0.1875) + 0.0625.
#
# If we convert this to a matrix with possible allele combination for each gene (HERE Dd would be a hetereozygous combination combination for gene one and Ee, a heterozygous combination for gene two), we have 16 possible combinations of 4 alleles. The table below displays the type of phenotype combination in different colours. The yellow colour displays the number of combinations which gives dominant expression of both phenotypes. The green boxes indicate the combinations that results in one phenotype being recessive. There is just one cell (blue) that displays the combination with both phenotypes being recessive. We can simply calculate the probabilities deviding the number of boxes in each type with 16:
#
# 0.5625 (= 9/16) + 2x0.1875 (=3/16) + 0.0625 (1/16) = 1
#
# You may notice that this indicates that gene combinations result in a Binomial distribution of probability of phentype combinations.

# %% [markdown]
# <img src="./images/Mendel2.png" width=800, height=300>

# %% [markdown]
# This approach can be generalised to a Polygenic Mendelian model where number of dominant vs. recessive alleles for each combination of n genes distribute according to a Binomial distribution (except the denominator is 4^n instead of 2^n). The sum of probability of “dominant gene” expression is always 0.75 and similarly for “recessive genes” = 0.25
#
# Below is the Mount Meru (Meru Prastara) or Yang Hui’s Triangle (explored by Jia Xian), respectively in India and China, later to be called Pascal’s Triangle in Europe. It explores the distribution of the Binomial Coefficient values associated with each term of a Binomial term. The sum of probabilities on each term (line of coeeficients below) add up to 1. It is assumed that these probabilities are independent. In ancient sciences, from chemistry and medicine to other measures, Binomial distribution is frequently recognised as a probability pattern for natural phenomena. Here we will apply this distribution to polygenic configurations. The difference between the normal Binomial distribution and the one below is that the denominator to estimate the probabilities is 4^n, instead of 2^n.

# %% [markdown]
# ### The diagram below demonstrates the MtMeru or Pascal's Triangle depicting the distribution of Binomial coeefients. The Binomial here refers to 2 different (dual) probabilities or outcomes. For Mendelian inheritance, we have four squares (Punnet square or contingency table) per gene with complete dominant and complete recessive expression at either end. Dominant expression for multiple genes always add up to a probability of 0.75 and the recessive expressions to 0.25. The second level of the coefficient distribution is for 1 gene (4^1). The next level indicates the 1,2,1 distribution in which the coeefieint multiplies combination with similar probabilities

# %% [markdown]
# <img src="./images/MtMeru.png" width=800, height=300>

# %% [markdown]
# ## Expanding the Binomial distribution to more than 3 Mendelian genes

# %% [markdown]
# The binomial-probabilities for combinations of 3 genes is demonstrated on the table below, with row 1 being the probabilities for dominantly expressed genes and row 2 for recessive genes. In binomial mathematics P(D) is normally assigned P(r) and P(r) (recessive) is assigned P(q).

# %% [markdown]
# <img src="./images/Mendel3.png" width=800, height=300>

# %% [markdown]
# Now there are 64 possible combinations which can be reduced to 27 combinations of 3 dominant phenotypes, 36 combinations of 2 dominant and 1 recessive phenotype, 9 combinations of 1 dominant and 2 recessive combinations and only 1 combination in which all 3 recessive phenotypes are present.
#
# The probabilities corresponding to these combinations are
# (0.75)3 = 0.422, 3 x(0.75)2(0.25) = 3x0.141, ), 3x(0.75)(0.25)2 =3x0.0469 = 0.141,
# (0.25)3 = 0.015
# 0.422 = (D,D,D), 0.422 = (D,D, R), 0.141 = (D,R,R) and 0.015 = (R,R,R)
#
# As expected, the 3 gene combinations have probabilities that can be calculated using the respective probabilities of dominant and recessive phenotypes and using the binomial coefficients (1,3,3,1)

# %% [markdown]
# <img src="./images/Mendel4.png" width=800, height=300>

# %% [markdown]
# The generalised binomial equation that calculates the column marginal (totals at the bottom of the column) is, $^{n}C_{r~}P(r)^{r}(1-P(r))^{n-r}$, where, $^{n}C_{r}$ is the binomial coefficient that can be found on the binomial distribution table and P(r) is the top row marginal giving the dominant gene expression probability. Notice that the probabilities in the top row are all, the estimates of probability for the corresponding number of dominant alleles to be expressed in a n-gene combination. Thus, in a polygenic Mendelian combination, it is the total probability of expression of all dominant alleles that add up to 0.75. Same argument can be applied to the expression of a recessive trait (second row).
# The formula for calculating the total mariginal probability of dominant expression is $𝛴_{r=0}^{n}(r)P(r)^{r}(1-P(r))^{n-r}$.
# Note that for 4 gene combinations, the following table demonstrates the breakdown of distribution out 256 possibilities:

# %% [markdown]
# <img src="./images/Mendel5.png" width=800, height=300>

# %% [markdown]
# ## Using a Heatmap to display Binomial Probability Distribution

# %% [markdown]
# Below, we demonstrate two different binomial probability distribution patterns, depending on if it is a symmetric distribution of probability (e.g. coin toss with all probabilities = 0.5) or a Mendelian one (0.75:0.25 distribution). First, we assume that the alleles have an equal probability of expression. The following code will plot the heat map for the probabilities. Examining the heat map will demonstrate that the maximum probability of expresion follows a relatively narrow band down the probability ladder.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def plot_binomial_heatmap(max_genes=12):
    """Generates a heatmap of binomial probabilities for gene expression."""
    n_values = np.arange(0, max_genes + 1)  # Number of genes (0 to 12)
    k_values = np.arange(0, max_genes + 1)  # Number of dominant traits expressed (0 to 12)
    prob_matrix = np.zeros((len(n_values), len(k_values)))
    
    # Calculate probabilities
    for i, n in enumerate(n_values):
        for j, k in enumerate(k_values):
            if k <= n:  # Only possible when k <= n
                prob_matrix[i, j] = stats.binom.pmf(k, n, 0.5)  # Assuming p=0.5 for dominant traits
    
    plt.figure(figsize=(12, 10))
    sns.heatmap(prob_matrix, annot=True, fmt=".3f", cmap="YlGnBu", 
                xticklabels=k_values, yticklabels=n_values,
                cbar_kws={'label': 'Probability'})
    plt.xlabel("Number of Dominant Traits Expressed (k)")
    plt.ylabel("Number of Genes (n)")
    plt.title("Binomial Distribution Probabilities for Gene Expression")
    plt.tight_layout()
    plt.show()

plot_binomial_heatmap()

# %% [markdown]
# If we now change the code to have the dominant probability to be 0.75, the maximum probability of expression follows a narrower band and shifted to the right (towards more dominant expression). This is of interest because Dingle etal (2015) and Dennis Noble's group have pointed out the impossibility of the human genome (with 30 000 genes) evolving without the pathways of evolution only exploring a tiny proportion of possibilities, due to those selected early, determining the evolutionary path. The above binomial pattern may provide us with a possible way to model why multiple genes may independently contribute to a narrow path of high probability. In reality, genes do not act independently, and gene interactions during evolution may narrow the prbable paths further. This idea will be explored as we gradually generalise the idea of polygenic inheritance from Mendelian to other forms including eventually includinmg gene-gene interactions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def plot_mendelian_heatmap(max_genes=12):
    """Generates a heatmap of Mendelian probabilities for gene expression."""
    n_values = np.arange(0, max_genes + 1)  # Number of genes (0 to 12)
    k_values = np.arange(0, max_genes + 1)  # Number of dominant traits expressed (0 to 12)
    prob_matrix = np.zeros((len(n_values), len(k_values)))
    
    # Calculate Mendelian probabilities with p=0.75
    for i, n in enumerate(n_values):
        for j, k in enumerate(k_values):
            if k <= n:  # Only possible when k <= n
                prob_matrix[i, j] = stats.binom.pmf(k, n, 0.75)  # p=0.75 for dominant traits
    
    plt.figure(figsize=(12, 10))
    heatmap = sns.heatmap(prob_matrix, annot=True, fmt=".3f", cmap="YlGnBu", 
                         xticklabels=k_values, yticklabels=n_values,
                         cbar_kws={'label': 'Probability'})
    
    plt.xlabel("Number of Dominant Traits Expressed (k)")
    plt.ylabel("Number of Genes (n)")
    plt.title("Mendelian Inheritance Probabilities for Gene Expression (p=0.75)")
    plt.tight_layout()
    plt.show()
plot_mendelian_heatmap()

# %% [markdown]
# ## Case of 4 genes and balance between probability of Dominant vs Recessive

# %% [markdown]
# We return to the previous table for probabilities of expression for the 4 gene Mendelian inheritance. The third column from the left demonstrates equal numbers of dominant and recessive alleles. This is of interest later regarding a concept called balanced-expression states. For this reason we will discuss this further for now.

# %% [markdown]
# <img src="./images/Mendel5.png" width=800, height=300>

# %% [markdown]
# The middle column above has equal porportions of dominant and recessive traits being expressed (2 D and 2 R for each 4 gene combination). There are 27 gene combinations for each of these trait combinations of all Dominant and all Recessive equal in frequency. The total probability for this column is 54/256 = 0.210 ~ 4C2(0.75)2(0.25)2 = 4!/4-2)!2! x (0.5625)(0.0625) = 6 x 0.0351.
#
# Here, the nCr is such that r is n/2 and, the probabilities for dominant and recessive expression are equal or balanced. There are 54 pairwise combinations of alleles, with only 2 dominant traits. It is best to consider such combinations (e.g. for genes D,E,F,G, the gene combinations may be DDEEffgg, or DdEeffgg to give the phenotype DEfg), in terms of how the gene combinations that lead to the dominant phenotype would configure (the other two phenotypes would always he two homozygous combination).
#
# Thus, we reduce the calculation to that of the number of dominant gene combinations that are possible for two genes. This number is 9.
#
# Next, considering 4 genes (four phenotypes), there would be 6 different ways in which these phenotypes could combine in pairs. Thus, we have the number of combinations of 2 dominant and two recessive phenotypes equal to 54.
#
# Here, there are 27 pairwise combinations that are dominant and 27 recessives. The idea of balanced probability of dominant and recessive expression can be applied to any ratio of marginal probabilities as shall be illustrated later (e.g. 0.8:0.2 instead of 0.75:0.25). We will use this as a deductive construct to make inferences about prevalence.

# %% [markdown]
# The binomial distribution above does not take into account the variability of expression of say the set of “dominant” genes (alleles), which might cause the 0.75 probability to change to a different marginal probability as suggested above.  We can attempt to vary the probabilities within the binomial distribution. However, attempting to vary the total probabilities (for dominant and recessive) from 0.75:0.25 ratio faces the overdispersion problem.

# %% [markdown]
# ## Moving from Mendelian probabilities to variable probability of expresion

# %% [markdown]
# The code below attempts to model variation of the dominant probability P(r) from 0.5 to 0.8. As is seen the curves plots are quite close to each other. It does not model natural data staisfactorily because the data is overdispersed compared to the model

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta, binom
from scipy.special import comb, betaln

# Set parameters
n_genes = 10

# Number of genes (trials)
alpha_priors = [n_genes*0.8, n_genes*0.75, n_genes*0.6, n_genes*0.5]  # Prior hyperparameters (α)
beta_priors = [n_genes*0.2, n_genes*0.25, n_genes*0.4, n_genes*0.5]   # Prior hyperparameters (β)

# Generate data
k_values = np.arange(0, n_genes + 1)

# Plot
plt.figure(figsize=(10, 6))
colors = ['#1f77b4','#6e33ff','#ff7f0e', '#2ca02c']

for i, (a, b) in enumerate(zip(alpha_priors, beta_priors)):
    # Compute Binomial PMF
    
    pmf =[ binom.pmf(k, n_genes, a/(a+b) ) for k in k_values]

    # Plot
    plt.plot(k_values, pmf, 'o-', color=colors[i], 
             label=f'P(r) ={a/n_genes}, P(n-r) ={b/n_genes}')
    
    # Overlay pure Binomial (for comparison)

plt.title(f'Binomial- Variable Penetrance (n = {n_genes} Genes)')
plt.xlabel('Number of Dominant Traits (k)')
plt.ylabel('Probability')
plt.xticks(k_values)
plt.legend()
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# The overdispersion problem can be resolved by using the beta-binomial distribution that explores the variation of probability of "dominant" expression continuously. This will be explored in the next chapter.
